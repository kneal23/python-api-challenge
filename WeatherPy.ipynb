# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

#Build query URL
query_url=url + "appid=" + weather_api_key + "&q=" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | utrik
# Processing Record 2 of Set 1 | settat
# Processing Record 3 of Set 1 | robertsport
# Processing Record 4 of Set 1 | berbera
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 7 of Set 1 | udachny
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | tazovsky
# Processing Record 10 of Set 1 | hawaiian paradise park
# Processing Record 11 of Set 1 | margaret river
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | west island
# Processing Record 14 of Set 1 | blackmans bay
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | markovo
# Processing Record 17 of Set 1 | stettler
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | st. john's
# Processing Record 21 of Set 1 | port mathurin
# Processing Record 22 of Set 1 | felipe carrillo puerto
# Processing Record 23 of Set 1 | medias
# Processing Record 24 of Set 1 | hamilton
# Processing Record 25 of Set 1 | machico
# Processing Record 26 of Set 1 | taoudenni
# Processing Record 27 of Set 1 | rio grande
# Processing Record 28 of Set 1 | puerto natales
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | atafu village
# Processing Record 31 of Set 1 | harper
# Processing Record 32 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 33 of Set 1 | birni n konni
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | manokwari
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | edinburgh of the seven seas
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | tulum
# Processing Record 41 of Set 1 | isafjordur
# Processing Record 42 of Set 1 | okahao
# Processing Record 43 of Set 1 | tonj
# Processing Record 44 of Set 1 | luderitz
# Processing Record 45 of Set 1 | goulburn
# Processing Record 46 of Set 1 | naze
# Processing Record 47 of Set 1 | otaru
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | olonkinbyen
# Processing Record 50 of Set 1 | awjilah
# Processing Record 0 of Set 2 | waitangi
# Processing Record 1 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | jayapura
# Processing Record 4 of Set 2 | qaqortoq
# Processing Record 5 of Set 2 | stanley
# Processing Record 6 of Set 2 | papatowai
# Processing Record 7 of Set 2 | egilsstadir
# Processing Record 8 of Set 2 | kwidzyn
# Processing Record 9 of Set 2 | invercargill
# Processing Record 10 of Set 2 | wailua homesteads
# Processing Record 11 of Set 2 | callao
# Processing Record 12 of Set 2 | benemerito de las americas
# Processing Record 13 of Set 2 | port lincoln
# Processing Record 14 of Set 2 | parauapebas
# Processing Record 15 of Set 2 | sagarejo
# Processing Record 16 of Set 2 | happy valley-goose bay
# Processing Record 17 of Set 2 | goba
# Processing Record 18 of Set 2 | araguaina
# Processing Record 19 of Set 2 | bridgewater
# Processing Record 20 of Set 2 | borogontsy
# Processing Record 21 of Set 2 | touros
# Processing Record 22 of Set 2 | badger
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | arno
# Processing Record 25 of Set 2 | la'ie
# Processing Record 26 of Set 2 | polyarnyy
# Processing Record 27 of Set 2 | bilibino
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | iskateley
# Processing Record 30 of Set 2 | tonghae
# Processing Record 31 of Set 2 | rongelap
# Processing Record 32 of Set 2 | dayr hafir
# Processing Record 33 of Set 2 | tual
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | parabel'
# Processing Record 37 of Set 2 | wuxue
# Processing Record 38 of Set 2 | nogliki
# Processing Record 39 of Set 2 | tucuma
# Processing Record 40 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 2 | chapaev
# Processing Record 42 of Set 2 | manismata
# Processing Record 43 of Set 2 | borkum
# Processing Record 44 of Set 2 | tomatlan
# Processing Record 45 of Set 2 | portland
# Processing Record 46 of Set 2 | yuzhno-kurilsk
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | greymouth
# Processing Record 49 of Set 2 | kuloy
# Processing Record 0 of Set 3 | pisco
# Processing Record 1 of Set 3 | malango
# Processing Record 2 of Set 3 | revda
# Processing Record 3 of Set 3 | ranohira
# City not found. Skipping...
# Processing Record 4 of Set 3 | constantia
# Processing Record 5 of Set 3 | nuku'alofa
# Processing Record 6 of Set 3 | bealanana
# Processing Record 7 of Set 3 | metlili chaamba
# Processing Record 8 of Set 3 | sal rei
# Processing Record 9 of Set 3 | grand falls-windsor
# Processing Record 10 of Set 3 | flin flon
# Processing Record 11 of Set 3 | at taj
# Processing Record 12 of Set 3 | berdigestyakh
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | fort bragg
# Processing Record 17 of Set 3 | afaahiti
# Processing Record 18 of Set 3 | gereida
# Processing Record 19 of Set 3 | mcrae
# Processing Record 20 of Set 3 | port hueneme
# Processing Record 21 of Set 3 | anloga
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | filadelfia
# Processing Record 24 of Set 3 | kijang
# Processing Record 25 of Set 3 | kish
# Processing Record 26 of Set 3 | tchibanga
# Processing Record 27 of Set 3 | lidkoping
# Processing Record 28 of Set 3 | jharsuguda
# Processing Record 29 of Set 3 | weno
# Processing Record 30 of Set 3 | waingapu
# Processing Record 31 of Set 3 | alesund
# Processing Record 32 of Set 3 | masterton
# Processing Record 33 of Set 3 | rampachodavaram
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | sinop
# Processing Record 36 of Set 3 | robore
# Processing Record 37 of Set 3 | encruzilhada do sul
# Processing Record 38 of Set 3 | alofi
# Processing Record 39 of Set 3 | lospalos
# Processing Record 40 of Set 3 | vorgashor
# Processing Record 41 of Set 3 | kapa'a
# Processing Record 42 of Set 3 | nuuk
# Processing Record 43 of Set 3 | novodvinsk
# Processing Record 44 of Set 3 | queenstown
# Processing Record 45 of Set 3 | altai
# Processing Record 46 of Set 3 | fale old settlement
# Processing Record 47 of Set 3 | byron bay
# Processing Record 48 of Set 3 | bratsk
# Processing Record 49 of Set 3 | talnakh
# Processing Record 0 of Set 4 | leh
# Processing Record 1 of Set 4 | arteche
# Processing Record 2 of Set 4 | new norfolk
# Processing Record 3 of Set 4 | enewetak
# Processing Record 4 of Set 4 | handan
# Processing Record 5 of Set 4 | zeribet el oued
# Processing Record 6 of Set 4 | salinas
# Processing Record 7 of Set 4 | mandan
# Processing Record 8 of Set 4 | kununurra
# Processing Record 9 of Set 4 | port blair
# Processing Record 10 of Set 4 | wanning
# Processing Record 11 of Set 4 | dzhangala
# Processing Record 12 of Set 4 | uliastay
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | el daein
# City not found. Skipping...
# Processing Record 16 of Set 4 | houlton
# Processing Record 17 of Set 4 | injambakkam
# City not found. Skipping...
# Processing Record 18 of Set 4 | mount pearl
# Processing Record 19 of Set 4 | landeck
# Processing Record 20 of Set 4 | phan thiet
# Processing Record 21 of Set 4 | qui nhon
# Processing Record 22 of Set 4 | mwaya
# Processing Record 23 of Set 4 | harstad
# Processing Record 24 of Set 4 | hun
# Processing Record 25 of Set 4 | labytnangi
# Processing Record 26 of Set 4 | farafangana
# Processing Record 27 of Set 4 | lillehammer
# Processing Record 28 of Set 4 | gaspe
# Processing Record 29 of Set 4 | el calafate
# Processing Record 30 of Set 4 | ratnagiri
# Processing Record 31 of Set 4 | bandarbeyla
# Processing Record 32 of Set 4 | jumla
# Processing Record 33 of Set 4 | eunapolis
# City not found. Skipping...
# Processing Record 34 of Set 4 | mezhdurechenskiy
# Processing Record 35 of Set 4 | geneina
# Processing Record 36 of Set 4 | chicxulub puerto
# City not found. Skipping...
# Processing Record 37 of Set 4 | adelaide
# Processing Record 38 of Set 4 | sukhobezvodnoye
# Processing Record 39 of Set 4 | mana
# Processing Record 40 of Set 4 | college
# Processing Record 41 of Set 4 | opuwo
# Processing Record 42 of Set 4 | chernyshevsk
# Processing Record 43 of Set 4 | pionerskiy
# Processing Record 44 of Set 4 | rmi capitol
# Processing Record 45 of Set 4 | bowen
# Processing Record 46 of Set 4 | aasiaat
# Processing Record 47 of Set 4 | khorugh
# Processing Record 48 of Set 4 | petrolina
# Processing Record 49 of Set 4 | pacocha
# Processing Record 0 of Set 5 | nagamangala
# Processing Record 1 of Set 5 | roma
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | kurgan
# Processing Record 4 of Set 5 | puerto colombia
# Processing Record 5 of Set 5 | sooke
# Processing Record 6 of Set 5 | mawlaik
# Processing Record 7 of Set 5 | ouistreham
# Processing Record 8 of Set 5 | vallenar
# Processing Record 9 of Set 5 | ghadamis
# Processing Record 10 of Set 5 | tolanaro
# Processing Record 11 of Set 5 | tsiombe
# Processing Record 12 of Set 5 | nadym
# Processing Record 13 of Set 5 | delijan
# Processing Record 14 of Set 5 | hammerfest
# Processing Record 15 of Set 5 | kisangani
# Processing Record 16 of Set 5 | belem de sao francisco
# Processing Record 17 of Set 5 | birjand
# Processing Record 18 of Set 5 | cabedelo
# Processing Record 19 of Set 5 | taltal
# Processing Record 20 of Set 5 | mersa matruh
# Processing Record 21 of Set 5 | pedro ii
# Processing Record 22 of Set 5 | konibodom
# Processing Record 23 of Set 5 | walvis bay
# Processing Record 24 of Set 5 | miyanoura
# City not found. Skipping...
# Processing Record 25 of Set 5 | morondava
# Processing Record 26 of Set 5 | el porvenir
# Processing Record 27 of Set 5 | mbekenyera
# Processing Record 28 of Set 5 | gamba
# Processing Record 29 of Set 5 | inhambane
# Processing Record 30 of Set 5 | flying fish cove
# Processing Record 31 of Set 5 | zambezi
# Processing Record 32 of Set 5 | inirida
# Processing Record 33 of Set 5 | bhamo
# Processing Record 34 of Set 5 | saint-philippe
# Processing Record 35 of Set 5 | bom jesus
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | lata
# Processing Record 38 of Set 5 | brazzaville
# Processing Record 39 of Set 5 | jamestown
# Processing Record 40 of Set 5 | nova sintra
# Processing Record 41 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 42 of Set 5 | akrehamn
# Processing Record 43 of Set 5 | jian'ou
# Processing Record 44 of Set 5 | codrington
# Processing Record 45 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 46 of Set 5 | lignano sabbiadoro
# Processing Record 47 of Set 5 | ambon
# Processing Record 48 of Set 5 | saipan
# Processing Record 49 of Set 5 | neiafu
# Processing Record 0 of Set 6 | puerto deseado
# Processing Record 1 of Set 6 | coahuayana de hidalgo
# Processing Record 2 of Set 6 | kosonsoy
# Processing Record 3 of Set 6 | hithadhoo
# Processing Record 4 of Set 6 | nema
# Processing Record 5 of Set 6 | nar'yan-mar
# Processing Record 6 of Set 6 | lihue
# Processing Record 7 of Set 6 | saynshand
# Processing Record 8 of Set 6 | madimba
# Processing Record 9 of Set 6 | balod
# Processing Record 10 of Set 6 | okhotsk
# Processing Record 11 of Set 6 | cabanas
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | ust-nera
# Processing Record 14 of Set 6 | dillingen an der donau
# Processing Record 15 of Set 6 | qamdo
# Processing Record 16 of Set 6 | eenhana
# Processing Record 17 of Set 6 | colonia
# Processing Record 18 of Set 6 | nadi
# Processing Record 19 of Set 6 | moron
# Processing Record 20 of Set 6 | bazar-e yakawlang
# City not found. Skipping...
# Processing Record 21 of Set 6 | amasra
# Processing Record 22 of Set 6 | severo-yeniseyskiy
# Processing Record 23 of Set 6 | susuman
# Processing Record 24 of Set 6 | whitehorse
# Processing Record 25 of Set 6 | chardara
# Processing Record 26 of Set 6 | carqueiranne
# Processing Record 27 of Set 6 | ola
# Processing Record 28 of Set 6 | chegdomyn
# Processing Record 29 of Set 6 | tsagan aman
# Processing Record 30 of Set 6 | arkhangel'sk
# Processing Record 31 of Set 6 | agat village
# Processing Record 32 of Set 6 | el bauga
# Processing Record 33 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 34 of Set 6 | kerikeri
# Processing Record 35 of Set 6 | aykhal
# Processing Record 36 of Set 6 | akure
# Processing Record 37 of Set 6 | warora
# Processing Record 38 of Set 6 | ingeniero jacobacci
# Processing Record 39 of Set 6 | aoji
# Processing Record 40 of Set 6 | dudinka
# Processing Record 41 of Set 6 | el nido
# Processing Record 42 of Set 6 | huarmey
# Processing Record 43 of Set 6 | stephenville
# Processing Record 44 of Set 6 | punta arenas
# Processing Record 45 of Set 6 | port elizabeth
# Processing Record 46 of Set 6 | cedartown
# Processing Record 47 of Set 6 | uruana
# Processing Record 48 of Set 6 | ebon
# Processing Record 49 of Set 6 | vernon
# Processing Record 0 of Set 7 | phuntsholing
# Processing Record 1 of Set 7 | albert lea
# Processing Record 2 of Set 7 | crane
# Processing Record 3 of Set 7 | boysun
# Processing Record 4 of Set 7 | baikonur
# Processing Record 5 of Set 7 | mineros
# Processing Record 6 of Set 7 | kotlas
# Processing Record 7 of Set 7 | bardai
# Processing Record 8 of Set 7 | klyuchi
# Processing Record 9 of Set 7 | anadyr
# Processing Record 10 of Set 7 | bambanglipuro
# Processing Record 11 of Set 7 | ed damer
# Processing Record 12 of Set 7 | nemuro
# Processing Record 13 of Set 7 | brainerd
# Processing Record 14 of Set 7 | caxito
# Processing Record 15 of Set 7 | bodo
# Processing Record 16 of Set 7 | shimoda
# Processing Record 17 of Set 7 | amboasary
# Processing Record 18 of Set 7 | ouesso
# Processing Record 19 of Set 7 | carnarvon
# Processing Record 20 of Set 7 | balikpapan
# Processing Record 21 of Set 7 | onsala
# Processing Record 22 of Set 7 | pont rouge
# Processing Record 23 of Set 7 | dunhua
# Processing Record 24 of Set 7 | rock springs
# Processing Record 25 of Set 7 | nasir
# Processing Record 26 of Set 7 | kapuskasing
# Processing Record 27 of Set 7 | chabahar
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | jianguang
# Processing Record 30 of Set 7 | salaga
# Processing Record 31 of Set 7 | siwa oasis
# Processing Record 32 of Set 7 | pangody
# Processing Record 33 of Set 7 | turpan
# Processing Record 34 of Set 7 | panaba
# Processing Record 35 of Set 7 | chirala
# Processing Record 36 of Set 7 | daru
# Processing Record 37 of Set 7 | novouzensk
# Processing Record 38 of Set 7 | visby
# Processing Record 39 of Set 7 | mizque
# Processing Record 40 of Set 7 | benguela
# Processing Record 41 of Set 7 | bereznik
# Processing Record 42 of Set 7 | kochenevo
# Processing Record 43 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 44 of Set 7 | la passe
# Processing Record 45 of Set 7 | alo
# Processing Record 46 of Set 7 | teknaf
# Processing Record 47 of Set 7 | timbuktu
# Processing Record 48 of Set 7 | maues
# Processing Record 49 of Set 7 | simiti
# Processing Record 0 of Set 8 | namibe
# Processing Record 1 of Set 8 | sierra grande
# Processing Record 2 of Set 8 | kavaratti
# Processing Record 3 of Set 8 | conde
# Processing Record 4 of Set 8 | hinton
# Processing Record 5 of Set 8 | howard springs
# Processing Record 6 of Set 8 | lagoa
# Processing Record 7 of Set 8 | oncativo
# Processing Record 8 of Set 8 | yanykurgan
# Processing Record 9 of Set 8 | gorodoviki
# Processing Record 10 of Set 8 | richards bay
# Processing Record 11 of Set 8 | akdepe
# Processing Record 12 of Set 8 | kayangel
# Processing Record 13 of Set 8 | arauco
# Processing Record 14 of Set 8 | mabaruma
# Processing Record 15 of Set 8 | khargupur
# Processing Record 16 of Set 8 | lafayette
# Processing Record 17 of Set 8 | magdagachi
# Processing Record 18 of Set 8 | baker city
# Processing Record 19 of Set 8 | seryshevo
# Processing Record 20 of Set 8 | tshikapa
# Processing Record 21 of Set 8 | vilyuysk
# Processing Record 22 of Set 8 | swiecie
# Processing Record 23 of Set 8 | isfara
# Processing Record 24 of Set 8 | hadibu
# Processing Record 25 of Set 8 | san rafael del sur
# Processing Record 26 of Set 8 | mahina
# Processing Record 27 of Set 8 | kargil
# Processing Record 28 of Set 8 | greenland
# Processing Record 29 of Set 8 | kingston
# Processing Record 30 of Set 8 | tura
# Processing Record 31 of Set 8 | quellon
# Processing Record 32 of Set 8 | patong
# Processing Record 33 of Set 8 | san luis de la loma
# Processing Record 34 of Set 8 | abu dhabi
# Processing Record 35 of Set 8 | bargaal
# Processing Record 36 of Set 8 | san julian
# Processing Record 37 of Set 8 | mostaganem
# Processing Record 38 of Set 8 | autazes
# Processing Record 39 of Set 8 | haiku-pauwela
# Processing Record 40 of Set 8 | sisimiut
# Processing Record 41 of Set 8 | salym
# Processing Record 42 of Set 8 | funafuti
# Processing Record 43 of Set 8 | vila velha
# Processing Record 44 of Set 8 | qarazhal
# Processing Record 45 of Set 8 | amahai
# Processing Record 46 of Set 8 | kananga
# Processing Record 47 of Set 8 | el granada
# Processing Record 48 of Set 8 | smithers
# Processing Record 49 of Set 8 | reggane
# Processing Record 0 of Set 9 | myitkyina
# Processing Record 1 of Set 9 | prado
# Processing Record 2 of Set 9 | muisne
# Processing Record 3 of Set 9 | gamay
# Processing Record 4 of Set 9 | liberal
# Processing Record 5 of Set 9 | dali
# Processing Record 6 of Set 9 | bedesa
# Processing Record 7 of Set 9 | gadzhiyevo
# Processing Record 8 of Set 9 | pathein
# Processing Record 9 of Set 9 | bogale
# Processing Record 10 of Set 9 | kristiansund
# Processing Record 11 of Set 9 | vilyuchinsk
# Processing Record 12 of Set 9 | bikenibeu village
# Processing Record 13 of Set 9 | tralee
# Processing Record 14 of Set 9 | eravur town
# Processing Record 15 of Set 9 | tinajo
# Processing Record 16 of Set 9 | ugoofaaru
# Processing Record 17 of Set 9 | oranjemund
# Processing Record 18 of Set 9 | sanctuary point
# Processing Record 19 of Set 9 | labuan bajo
# Processing Record 20 of Set 9 | bamenda
# Processing Record 21 of Set 9 | rahuri
# Processing Record 22 of Set 9 | newman
# Processing Record 23 of Set 9 | prince rupert
# Processing Record 24 of Set 9 | bang nam priao
# Processing Record 25 of Set 9 | ternate
# Processing Record 26 of Set 9 | fada
# Processing Record 27 of Set 9 | shangmei
# Processing Record 28 of Set 9 | tamandare
# Processing Record 29 of Set 9 | raduzhny
# Processing Record 30 of Set 9 | ras gharib
# City not found. Skipping...
# Processing Record 31 of Set 9 | reuleuet
# Processing Record 32 of Set 9 | selu
# Processing Record 33 of Set 9 | wajir
# Processing Record 34 of Set 9 | riachao das neves
# Processing Record 35 of Set 9 | olyokminsk
# Processing Record 36 of Set 9 | vila franca do campo
# Processing Record 37 of Set 9 | selfoss
# Processing Record 38 of Set 9 | qujing
# Processing Record 39 of Set 9 | san antonio de pale
# Processing Record 40 of Set 9 | abeche
# Processing Record 41 of Set 9 | christchurch
# Processing Record 42 of Set 9 | labrador city
# Processing Record 43 of Set 9 | tyukalinsk
# Processing Record 44 of Set 9 | mao
# Processing Record 45 of Set 9 | las veredas
# Processing Record 46 of Set 9 | island harbour
# Processing Record 47 of Set 9 | manzini
# Processing Record 48 of Set 9 | fuglafjordur
# Processing Record 49 of Set 9 | mugia
# Processing Record 0 of Set 10 | tosontsengel
# Processing Record 1 of Set 10 | remire-montjoly
# Processing Record 2 of Set 10 | alice springs
# Processing Record 3 of Set 10 | bodaybo
# Processing Record 4 of Set 10 | richmond
# Processing Record 5 of Set 10 | barcelos
# Processing Record 6 of Set 10 | rosetta
# Processing Record 7 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 10 | tercan
# Processing Record 9 of Set 10 | fort st. john
# Processing Record 10 of Set 10 | socorro
# Processing Record 11 of Set 10 | bermeo
# Processing Record 12 of Set 10 | modimolle
# Processing Record 13 of Set 10 | souillac
# Processing Record 14 of Set 10 | shohimardon
# Processing Record 15 of Set 10 | ponta delgada
# Processing Record 16 of Set 10 | misratah
# Processing Record 17 of Set 10 | broken hill
# Processing Record 18 of Set 10 | kidal
# Processing Record 19 of Set 10 | mangrol
# Processing Record 20 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 21 of Set 10 | nizhniy kuranakh
# Processing Record 22 of Set 10 | east london
# Processing Record 23 of Set 10 | valparaiso
# Processing Record 24 of Set 10 | pyt-yakh
# Processing Record 25 of Set 10 | puerto baquerizo moreno
# Processing Record 26 of Set 10 | monte alegre
# Processing Record 27 of Set 10 | kokkola
# Processing Record 28 of Set 10 | adiake
# Processing Record 29 of Set 10 | noumea
# Processing Record 30 of Set 10 | luebo
# Processing Record 31 of Set 10 | uman
# Processing Record 32 of Set 10 | baile herculane
# Processing Record 33 of Set 10 | babu
# Processing Record 34 of Set 10 | orcopampa
# Processing Record 35 of Set 10 | la quiaca
# Processing Record 36 of Set 10 | longuyon
# Processing Record 37 of Set 10 | lautoka
# Processing Record 38 of Set 10 | majuro
# Processing Record 39 of Set 10 | monchegorsk
# Processing Record 40 of Set 10 | vadso
# Processing Record 41 of Set 10 | mokwa
# Processing Record 42 of Set 10 | ust'-uda
# Processing Record 43 of Set 10 | quang ngai
# Processing Record 44 of Set 10 | saudarkrokur
# Processing Record 45 of Set 10 | ha tinh
# Processing Record 46 of Set 10 | bitkine
# Processing Record 47 of Set 10 | laguna
# Processing Record 48 of Set 10 | saint-joseph
# Processing Record 49 of Set 10 | al qubbah
# Processing Record 0 of Set 11 | palmer
# Processing Record 1 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 2 of Set 11 | yulinshi
# Processing Record 3 of Set 11 | itoman
# Processing Record 4 of Set 11 | fortuna
# Processing Record 5 of Set 11 | ambalangoda
# Processing Record 6 of Set 11 | tazacorte
# Processing Record 7 of Set 11 | nizhnesortymskiy
# Processing Record 8 of Set 11 | horishni plavni
# Processing Record 9 of Set 11 | aleg
# Processing Record 10 of Set 11 | guerrero negro
# Processing Record 11 of Set 11 | hami
# Processing Record 12 of Set 11 | makary
# Processing Record 13 of Set 11 | zmeinogorsk
# Processing Record 14 of Set 11 | vuktyl
# Processing Record 15 of Set 11 | xuddur
# Processing Record 16 of Set 11 | winters
# Processing Record 17 of Set 11 | phayao
# Processing Record 18 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 11 | pasargad
# City not found. Skipping...
# Processing Record 20 of Set 11 | bin yauri
# Processing Record 21 of Set 11 | boende
# Processing Record 22 of Set 11 | wusong
# Processing Record 23 of Set 11 | mumford
# Processing Record 24 of Set 11 | jennings
# Processing Record 25 of Set 11 | puerto san carlos
# City not found. Skipping...
# Processing Record 26 of Set 11 | tromso
# Processing Record 27 of Set 11 | mukalla
# Processing Record 28 of Set 11 | tamanrasset
# Processing Record 29 of Set 11 | safi
# Processing Record 30 of Set 11 | bandar abbas
# Processing Record 31 of Set 11 | yasuj
# Processing Record 32 of Set 11 | horta
# Processing Record 33 of Set 11 | faya-largeau
# Processing Record 34 of Set 11 | goure
# Processing Record 35 of Set 11 | basoko
# Processing Record 36 of Set 11 | papao
# Processing Record 37 of Set 11 | rikaze
# Processing Record 38 of Set 11 | uturoa
# Processing Record 39 of Set 11 | castillos
# Processing Record 40 of Set 11 | nacala
# Processing Record 41 of Set 11 | porto seguro
# Processing Record 42 of Set 11 | dadukou
# Processing Record 43 of Set 11 | murun-kuren
# Processing Record 44 of Set 11 | coquimbo
# Processing Record 45 of Set 11 | bati
# Processing Record 46 of Set 11 | naha
# Processing Record 47 of Set 11 | minusinsk
# Processing Record 48 of Set 11 | pine bluff
# Processing Record 49 of Set 11 | la puebla de montalban
# Processing Record 0 of Set 12 | katsuren-haebaru
# Processing Record 1 of Set 12 | mahdia
# Processing Record 2 of Set 12 | paredon
# Processing Record 3 of Set 12 | antofagasta
# Processing Record 4 of Set 12 | tateyama
# Processing Record 5 of Set 12 | bougouni
# Processing Record 6 of Set 12 | timimoun
# Processing Record 7 of Set 12 | kapit
# Processing Record 8 of Set 12 | maputo
# Processing Record 9 of Set 12 | keflavik
# Processing Record 10 of Set 12 | port saint john's
# Processing Record 11 of Set 12 | mpika
# Processing Record 12 of Set 12 | ta`u
# Processing Record 13 of Set 12 | verkhnevilyuysk
# Processing Record 14 of Set 12 | tabuk
# Processing Record 15 of Set 12 | carbonear
# Processing Record 16 of Set 12 | jasper
# Processing Record 17 of Set 12 | general acha
# Processing Record 18 of Set 12 | venilale
# City not found. Skipping...
# Processing Record 19 of Set 12 | change
# Processing Record 20 of Set 12 | jeddah
# Processing Record 21 of Set 12 | la ronge
# Processing Record 22 of Set 12 | afif
# Processing Record 23 of Set 12 | windhoek
# Processing Record 24 of Set 12 | guiuan
# Processing Record 25 of Set 12 | mont-dore
# Processing Record 26 of Set 12 | la sarre
# Processing Record 27 of Set 12 | as sulayyil
# Processing Record 28 of Set 12 | burang
# Processing Record 29 of Set 12 | talcahuano
# Processing Record 30 of Set 12 | ribeira brava
# Processing Record 31 of Set 12 | dalhart
# Processing Record 32 of Set 12 | nangen
# Processing Record 33 of Set 12 | saint-francois
# Processing Record 34 of Set 12 | lerwick
# Processing Record 35 of Set 12 | eufaula
# Processing Record 36 of Set 12 | kroya
# Processing Record 37 of Set 12 | holualoa
# Processing Record 38 of Set 12 | cannonvale
# Processing Record 39 of Set 12 | necocli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          568
# Lat           568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        utrik  11.2278  169.8474    300.04        86          98        8.77
# 1       settat  33.0007   -7.6204    290.05        71          71        4.89
# 2  robertsport   6.7533  -11.3686    301.31        84         100        5.04
# 3      berbera  10.4396   45.0143    303.04        75          13        2.17
# 4       bethel  41.3712  -73.4140    289.46        34           0        3.09
#
#   Country        Date
# 0      MH  1713818069
# 1      MA  1713818360
# 2      LR  1713818363
# 3      SO  1713818139
# 4      US  1713817948

# %%
#Output Directory setup
output_file = "../WeatherPy/cities.csv"


# Export the City_Data into a csv
city_data_df.to_csv(output_file, index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../WeatherPy/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              utrik  11.2278  169.8474    300.04        86          98
# 1             settat  33.0007   -7.6204    290.05        71          71
# 2        robertsport   6.7533  -11.3686    301.31        84         100
# 3            berbera  10.4396   45.0143    303.04        75          13
# 4             bethel  41.3712  -73.4140    289.46        34           0
#
#          Wind Speed Country        Date
# City_ID
# 0              8.77      MH  1713818069
# 1              4.89      MA  1713818360
# 2              5.04      LR  1713818363
# 3              2.17      SO  1713818139
# 4              3.09      US  1713817948

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg(df, y_value):
# Scatter plot
    plt.scatter(df['Lat'], df[y_value])
    plt.title("Latitude vs " + y_value)
    plt.xlabel("Latitude")
    plt.ylabel(y_value)
    
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(df['Lat'], df[y_value])
    
    # Plot regression line
    plt.plot(df['Lat'], slope * df['Lat'] + intercept, color='red')
    
    # Add equation of the line
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}\nR-value = {r_value:.2f}"
    plt.annotate(line_eq, (df['Lat'].min(), df[y_value].max()), fontsize=12, color="red")
    
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              utrik  11.2278  169.8474    300.04        86          98
# 1             settat  33.0007   -7.6204    290.05        71          71
# 2        robertsport   6.7533  -11.3686    301.31        84         100
# 3            berbera  10.4396   45.0143    303.04        75          13
# 4             bethel  41.3712  -73.4140    289.46        34           0
#
#          Wind Speed Country        Date
# City_ID
# 0              8.77      MH  1713818069
# 1              4.89      MA  1713818360
# 2              5.04      LR  1713818363
# 3              2.17      SO  1713818139
# 4              3.09      US  1713817948

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 9        margaret river -33.9500  115.0667    285.87        57          91
# 10            geraldton -28.7667  114.6000    290.38        55          97
# 11          west island -12.1568   96.8225    300.14        94          75
# 12        blackmans bay -43.0167  147.3167    283.44        83         100
# 13           bredasdorp -34.5322   20.0403    289.26        91          99
#
#          Wind Speed Country        Date
# City_ID
# 9              3.86      AU  1713817955
# 10             8.75      AU  1713818209
# 11             7.72      CC  1713818018
# 12             1.34      AU  1713818005
# 13             0.89      ZA  1713817946

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_reg(northern_hemi_df, "Max Temp")

# %%
# Linear regression on Southern Hemisphere
lin_reg(southern_hemi_df, "Max Temp")

# %% [markdown]
# **Discussion about the linear relationship:** There is a negative relationship between latitude and max temp in the northern hemisphere. As
# the latitude increases, the temperature decreases. This is the inverse for the southern hemisphere. At the latitude increases, the max temperature also increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg(northern_hemi_df, "Humidity")

# %%
# Southern Hemisphere
lin_reg(southern_hemi_df, "Humidity")

# %% [markdown]
# **Discussion about the linear relationship:** Give the data above, there is no correlation that can be drawn regarding humidity and latitude with the given R-values.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg(northern_hemi_df, "Cloudiness")

# %%
# Southern Hemisphere
lin_reg(southern_hemi_df, "Cloudiness")

# %% [markdown]
# **Discussion about the linear relationship:** Give the data above, there is no correlation that can be drawn regarding cloudiness and latitude with the given R-values.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg(northern_hemi_df, "Wind Speed")

# %%
# Southern Hemisphere
lin_reg(southern_hemi_df, "Wind Speed")

# %% [markdown]
# **Discussion about the linear relationship:** Give the data above, there is no correlation that can be drawn regarding wind speed and latitude with the given R-values.
